# %%
import pandas as pd

# %%
test_2019 = pd.read_csv('../know_Data/test/KNOW_2019_test(2) - 복원.csv')

# %%
test_2019.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8554 entries, 0 to 8553
# Data columns (total 152 columns):
#  #    Column   Dtype
# ---   ------   -----
#  0    idx      int64
#  1    sq1      int64
#  2    sq2      int64
#  3    sq3      int64
#  4    sq4      int64
#  5    sq5      int64
#  6    sq6      int64
#  7    sq7      int64
#  8    sq8      int64
#  9    sq9      int64
#  10   sq10     int64
#  11   sq11     int64
#  12   sq12     int64
#  13   sq13     int64
#  14   sq14     int64
#  15   sq15     int64
#  16   sq16     int64
#  17   kq1_1    int64
#  18   kq1_2    int64
#  19   kq2_1    int64
#  20   kq2_2    int64
#  21   kq3_1    int64
#  22   kq3_2    int64
#  23   kq4_1    int64
#  24   kq4_2    int64
#  25   kq5_1    int64
#  26   kq5_2    int64
#  27   kq6_1    int64
#  28   kq6_2    int64
#  29   kq7_1    int64
#  30   kq7_2    int64
#  31   kq8_1    int64
#  32   kq8_2    int64
#  33   kq9_1    int64
#  34   kq9_2    int64
#  35   kq10_1   int64
#  36   kq10_2   int64
#  37   kq11_1   int64
#  38   kq11_2   int64
#  39   kq12_1   int64
#  40   kq12_2   int64
#  41   kq13_1   int64
#  42   kq13_2   int64
#  43   kq14_1   int64
#  44   kq14_2   int64
#  45   kq15_1   int64
#  46   kq15_2   int64
#  47   kq16_1   int64
#  48   kq16_2   int64
#  49   kq17_1   int64
#  50   kq17_2   int64
#  51   kq18_1   int64
#  52   kq18_2   int64
#  53   kq19_1   int64
#  54   kq19_2   int64
#  55   kq20_1   int64
#  56   kq20_2   int64
#  57   kq21_1   int64
#  58   kq21_2   int64
#  59   kq22_1   int64
#  60   kq22_2   int64
#  61   kq23_1   int64
#  62   kq23_2   int64
#  63   kq24_1   int64
#  64   kq24_2   int64
#  65   kq25_1   int64
#  66   kq25_2   int64
#  67   kq26_1   int64
#  68   kq26_2   int64
#  69   kq27_1   int64
#  70   kq27_2   int64
#  71   kq28_1   int64
#  72   kq28_2   int64
#  73   kq29_1   int64
#  74   kq29_2   int64
#  75   kq30_1   int64
#  76   kq30_2   int64
#  77   kq31_1   int64
#  78   kq31_2   int64
#  79   kq32_1   int64
#  80   kq32_2   int64
#  81   kq33_1   int64
#  82   kq33_2   int64
#  83   bq1      int64
#  84   bq2      int64
#  85   bq3      int64
#  86   bq4      int64
#  87   bq4_1a   object
#  88   bq4_1b   object
#  89   bq4_1c   object
#  90   bq5      int64
#  91   bq5_1    object
#  92   bq5_2    object
#  93   bq6      int64
#  94   bq7      int64
#  95   bq8_1    int64
#  96   bq8_2    int64
#  97   bq8_3    int64
#  98   bq9      int64
#  99   bq10     int64
#  100  bq11     int64
#  101  bq12_1   int64
#  102  bq12_2   int64
#  103  bq12_3   int64
#  104  bq12_4   int64
#  105  bq12_5   int64
#  106  bq13_1   int64
#  107  bq13_2   int64
#  108  bq13_3   int64
#  109  bq14_1   int64
#  110  bq14_2   int64
#  111  bq14_3   int64
#  112  bq14_4   int64
#  113  bq14_5   int64
# bq21_2 5
# bq21_3 5
# bq22 1868
# bq23 1769
# bq24 635
# bq25 2
# bq26 65
# bq27 6
# bq27_1 1875
# bq28 2
# bq28_1 5
# bq28_2 4
# bq29 3
# bq30 70
# bq31_1 255
# bq31_2 165
# bq31_3 108

# %%
test_2019.bq29.value_counts()
# Out:
# 1    6184
#      1228
# 2    1142
# Name: bq29, dtype: int64

# %% [markdown]
# 1. 결측치
#
# - 주관식이라 버릴 항목
# bq22         1
# bq24       2
#
# - 처리해야하는 항목
# bq31_3   근로소득  2
#
#
# 2. 이상치
#
# 수작업으로 밀린 것 처리
#
# 3. 주관식
#
# - 자격증
# bq4_1a 1559
# bq4_1b 710
# bq4_1c 265
#
# - 버림
# bq5_2 3263
# bq18_10 2588
# bq20_1 6355
# bq22 1868
# bq23 1769
# bq24 635
#
# - 학과
# bq27_1 1875
#
# 4. 숫자여야하는 col
# bq26 65
# bq30 70
# bq31_1 255
# bq31_2 165
# bq31_3 108
#
# 5. 체크해봐야할 col
#
# bq29 3 & bq28

# %%
for col in test_2019:
        test_2019[col].replace(' ', 0, inplace = True)

# %%
# 주관식문항 

str_li =['bq4_1a','bq4_1b','bq4_1c','bq5_2', 'bq18_10','bq20_1','bq22','bq23','bq24', 'bq27_1']

# %%
test_2019 = test_2019.fillna(0)

# %%
test_2019.isnull().sum()[100:]
# Out:
# bq11       0
# bq12_1     0
# bq12_2     0
# bq12_3     0
# bq12_4     0
# bq12_5     0
# bq13_1     0
# bq13_2     0
# bq13_3     0
# bq14_1     0
# bq14_2     0
# bq14_3     0
# bq14_4     0
# bq14_5     0
# bq15       0
# bq16_1     0
# bq16_2     0
# bq16_3     0
# bq16_4     0
# bq16_5     0
# bq17       0
# bq18_1     0
# bq18_2     0
# bq18_3     0
# bq18_4     0
# bq18_5     0
# bq18_6     0
# bq18_7     0
# bq18_8     0
# bq18_9     0
# bq18_10    0
# bq19       0
# bq20       0
# bq20_1     0
# bq21_1     0
# bq21_2     0
# bq21_3     0
# bq22       0
# bq23       0
# bq24       0
# bq25       0
# bq26       0
# bq27       0
# bq27_1     0
# bq28       0
# bq28_1     0
# bq28_2     0
# bq29       0
# bq30       0
# bq31_1     0
# bq31_2     0
# bq31_3     0
# dtype: int64

# %%
# int형으로 바꾸기 위해서 1.null 값처리 2. bq30 번에 37.5 float 형 처리 필요함 
# train과 동일하게 시간을 float로 처리할지

for i in test_2019.columns : 
#     if i == 'bq30':
#         know_2019[i] = know_2019[i].astype(float)
    if i not in str_li : 
        test_2019[i] = test_2019[i].astype(int)
    else :
        test_2019[i] = test_2019[i].astype(str)

# %%
# _1 에서 1을 선택한 사람중 _2 답변을 한 사람이 있는지 확인

for i in range(33) :
    str5 = 'kq' + str(i+1) +'_1'
    str6 = 'kq' + str(i+1) +'_2'
    
    print(test_2019[(test_2019[str5]==1) & (test_2019[str6]!=0)][str6])
# Out:
# Series([], Name: kq1_2, dtype: int32)
# Series([], Name: kq2_2, dtype: int32)
# Series([], Name: kq3_2, dtype: int32)
# Series([], Name: kq4_2, dtype: int32)
# Series([], Name: kq5_2, dtype: int32)
# Series([], Name: kq6_2, dtype: int32)
# Series([], Name: kq7_2, dtype: int32)
# Series([], Name: kq8_2, dtype: int32)
# Series([], Name: kq9_2, dtype: int32)
# Series([], Name: kq10_2, dtype: int32)
# Series([], Name: kq11_2, dtype: int32)
# Series([], Name: kq12_2, dtype: int32)
# Series([], Name: kq13_2, dtype: int32)
# Series([], Name: kq14_2, dtype: int32)
# Series([], Name: kq15_2, dtype: int32)
# Series([], Name: kq16_2, dtype: int32)
# Series([], Name: kq17_2, dtype: int32)
# Series([], Name: kq18_2, dtype: int32)
# Series([], Name: kq19_2, dtype: int32)
# Series([], Name: kq20_2, dtype: int32)
# Series([], Name: kq21_2, dtype: int32)
# Series([], Name: kq22_2, dtype: int32)
# Series([], Name: kq23_2, dtype: int32)
# Series([], Name: kq24_2, dtype: int32)
# Series([], Name: kq25_2, dtype: int32)
# Series([], Name: kq26_2, dtype: int32)
# Series([], Name: kq27_2, dtype: int32)
# Series([], Name: kq28_2, dtype: int32)
# Series([], Name: kq29_2, dtype: int32)
# Series([], Name: kq30_2, dtype: int32)
# Series([], Name: kq31_2, dtype: int32)
# Series([], Name: kq32_2, dtype: int32)
# Series([], Name: kq33_2, dtype: int32)

# %%
# 답변이 있어야하는 셀 중 빈셀 있는지 확인 

for i in range(33) :
    str5 = 'kq' + str(i+1) +'_1'
    str6 = 'kq' + str(i+1) +'_2'
    
    print(test_2019[(test_2019[str5].isin([2,3,4,5])) & (test_2019[str6]==0)][str6])
# Out:
# Series([], Name: kq1_2, dtype: int32)
# Series([], Name: kq2_2, dtype: int32)
# Series([], Name: kq3_2, dtype: int32)
# Series([], Name: kq4_2, dtype: int32)
# Series([], Name: kq5_2, dtype: int32)
# Series([], Name: kq6_2, dtype: int32)
# Series([], Name: kq7_2, dtype: int32)
# Series([], Name: kq8_2, dtype: int32)
# Series([], Name: kq9_2, dtype: int32)
# Series([], Name: kq10_2, dtype: int32)
# Series([], Name: kq11_2, dtype: int32)
# Series([], Name: kq12_2, dtype: int32)
# Series([], Name: kq13_2, dtype: int32)
# Series([], Name: kq14_2, dtype: int32)
# Series([], Name: kq15_2, dtype: int32)
# Series([], Name: kq16_2, dtype: int32)
# Series([], Name: kq17_2, dtype: int32)
# Series([], Name: kq18_2, dtype: int32)
# Series([], Name: kq19_2, dtype: int32)
# Series([], Name: kq20_2, dtype: int32)
# Series([], Name: kq21_2, dtype: int32)
# Series([], Name: kq22_2, dtype: int32)
# Series([], Name: kq23_2, dtype: int32)
# Series([], Name: kq24_2, dtype: int32)
# Series([], Name: kq25_2, dtype: int32)
# Series([], Name: kq26_2, dtype: int32)
# Series([], Name: kq27_2, dtype: int32)
# Series([], Name: kq28_2, dtype: int32)
# Series([], Name: kq29_2, dtype: int32)
# Series([], Name: kq30_2, dtype: int32)
# Series([], Name: kq31_2, dtype: int32)
# Series([], Name: kq32_2, dtype: int32)
# Series([], Name: kq33_2, dtype: int32)

# %%
# bq27=1(중졸)인 사람중 학과 입력한 사람
test_2019[(test_2019.bq27==1) & (test_2019.bq27_1!='0')]['bq27_1'].value_counts()
# Out:
# 없음       8
# 한목건축과    1
# Name: bq27_1, dtype: int64

# %%
null_li5 = test_2019[(test_2019.bq27==1) & (test_2019.bq27_1!='0')].index
null_li5
# Out:
# Int64Index([719, 2601, 3923, 4897, 5696, 6006, 7252, 7272, 7820], dtype='int64')

# %%
for i in null_li5 :
    test_2019.iloc[i,143] = '0'

# %%
null_li5 = test_2019[(test_2019.bq27==1) & (test_2019.bq27_1!='0')].index
null_li5
# Out:
# Int64Index([], dtype='int64')

# %%
# 고졸 이상중 학과 입력안한 사람 
# 앞에서 '' 을 0 으로 replace했기 때문에 0으로 찾아야함 
test_2019[(test_2019.bq27.isin([2,3,4,5,6])) & (test_2019.bq27_1==0)]['bq27'].value_counts()
# Out:
# Series([], Name: bq27, dtype: int64)

# %%
# 근로시간

null_li = test_2019[test_2019.bq30==0].index
null_li
# Out:
# Int64Index([ 152,  281,  442,  811, 1288, 1465, 2092, 2231, 2606, 2728, 3069,
#             3493, 3818, 4274, 4758, 4845, 4860, 6109, 6499, 7336, 7621, 8460],
#            dtype='int64')

# %%
for i in null_li:
      test_2019.iloc[i,148]=round(test_2019[(test_2019.bq1 ==test_2019.iloc[i,83])&(test_2019.bq30!=0)].bq30.median())

# %%
null_li = test_2019[test_2019.bq30==0].index
null_li
# Out:
# Int64Index([], dtype='int64')

# %%
## 근로소득(임금근로자)

null_li2 = test_2019[(test_2019.bq28==1) & (test_2019.bq31_1==0)].index
null_li2
# Out:
# Int64Index([  89,  150,  181,  260,  294,  313,  328,  364,  419,  459,
#             ...
#             8034, 8072, 8083, 8114, 8136, 8152, 8168, 8357, 8437, 8464],
#            dtype='int64', length=155)

# %%
for i in null_li2:
      test_2019.iloc[i,149] = round(test_2019[(test_2019.bq1 ==test_2019.iloc[i,83])&(test_2019.bq31_1!=0)].bq31_1.median())

# %%
null_li2 = test_2019[(test_2019.bq28==1) & (test_2019.bq31_1==0)].index
null_li2
# Out:
# Int64Index([], dtype='int64')

# %%
null_li3 = test_2019[(test_2019.bq28==1) & (test_2019.bq31_2==0)].index
null_li3
# Out:
# Int64Index([ 150,  162,  181,  247,  294,  313,  354,  364,  397,  432,
#             ...
#             8172, 8200, 8213, 8220, 8259, 8357, 8432, 8453, 8464, 8466],
#            dtype='int64', length=249)

# %%
for i in null_li3:
      test_2019.iloc[i,150] = round(test_2019[(test_2019.bq1 ==test_2019.iloc[i,83])&(test_2019.bq31_2!=0)].bq31_2.median())

# %%
null_li3 = test_2019[(test_2019.bq28==1) & (test_2019.bq31_2==0)].index
null_li3
# Out:
# Int64Index([], dtype='int64')

# %%
null_li4 = test_2019[(test_2019.bq28==2) & (test_2019.bq31_3==0)].index
null_li4
# Out:
# Int64Index([ 140,  439,  510,  747,  829,  866, 1005, 1092, 1188, 1240, 1441,
#             1461, 1628, 1655, 1694, 1755, 1889, 1943, 2049, 2068, 2094, 2215,
#             2740, 2767, 2793, 2814, 2856, 3073, 3173, 3388, 3408, 3511, 3635,
#             3779, 3835, 4018, 4179, 4712, 4758, 5187, 5275, 5323, 5710, 6093,
#             6464, 6496, 6527, 6771, 7094, 7103, 7110, 7156, 7572, 7860, 8091,
#             8314, 8488],
#            dtype='int64')

# %%
for i in null_li4:
      test_2019.iloc[i,151] = round(test_2019[(test_2019.bq1 ==test_2019.iloc[i,83])&(test_2019.bq31_3!=0)].bq31_3.median())

# %%
null_li4 = test_2019[(test_2019.bq28==2) & (test_2019.bq31_3==0)].index
null_li4
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# 답변이 있어야하는 셀 중 빈셀 있는지 확인
#
# 1. 주관식으로 버릴 항목
# bq18_10
# bq20_1
#
# 2. 학과
# bq27_1 bq27 23456인데 학과 공백 많음
#        bq27 1 인 사람 중 없음으로 기재한 사람이 있음
#
# 3. 근로시간
# bq30 윗 셀 참조
#
# 4. 근로소득
# 종사하고 있는 산업의 평균값으로 처리할 예정
#
# bq31_1
# bq31_2
# 윗셀 참조
#
# bq31_3

# %%
test_2019.to_csv("know_2019_test_enutf.csv", encoding='utf8', index=False)
test_2019.to_csv("know_2019_test_encp.csv", encoding='cp949', index=False)

# %%
df_cp = pd.read_csv("know_2019_test_encp.csv", encoding='cp949')
df_cp.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8554 entries, 0 to 8553
# Data columns (total 152 columns):
#  #    Column   Dtype
# ---   ------   -----
#  0    idx      int64
#  1    sq1      int64
#  2    sq2      int64
#  3    sq3      int64
#  4    sq4      int64
#  5    sq5      int64
#  6    sq6      int64
#  7    sq7      int64
#  8    sq8      int64
#  9    sq9      int64
#  10   sq10     int64
#  11   sq11     int64
#  12   sq12     int64
#  13   sq13     int64
#  14   sq14     int64
#  15   sq15     int64
#  16   sq16     int64
#  17   kq1_1    int64
#  18   kq1_2    int64
#  19   kq2_1    int64
#  20   kq2_2    int64
#  21   kq3_1    int64
#  22   kq3_2    int64
#  23   kq4_1    int64
#  24   kq4_2    int64
#  25   kq5_1    int64
#  26   kq5_2    int64
#  27   kq6_1    int64
#  28   kq6_2    int64
#  29   kq7_1    int64
#  30   kq7_2    int64
#  31   kq8_1    int64
#  32   kq8_2    int64
#  33   kq9_1    int64
#  34   kq9_2    int64
#  35   kq10_1   int64
#  36   kq10_2   int64
#  37   kq11_1   int64
#  38   kq11_2   int64
#  39   kq12_1   int64
#  40   kq12_2   int64
#  41   kq13_1   int64
#  42   kq13_2   int64
#  43   kq14_1   int64
#  44   kq14_2   int64
#  45   kq15_1   int64
#  46   kq15_2   int64
#  47   kq16_1   int64
#  48   kq16_2   int64
#  49   kq17_1   int64
#  50   kq17_2   int64
#  51   kq18_1   int64
#  52   kq18_2   int64
#  53   kq19_1   int64
#  54   kq19_2   int64
#  55   kq20_1   int64
#  56   kq20_2   int64
#  57   kq21_1   int64
#  58   kq21_2   int64
#  59   kq22_1   int64
#  60   kq22_2   int64
#  61   kq23_1   int64
#  62   kq23_2   int64
#  63   kq24_1   int64
#  64   kq24_2   int64
#  65   kq25_1   int64
#  66   kq25_2   int64
#  67   kq26_1   int64
#  68   kq26_2   int64
#  69   kq27_1   int64
#  70   kq27_2   int64
#  71   kq28_1   int64
#  72   kq28_2   int64
#  73   kq29_1   int64
#  74   kq29_2   int64
#  75   kq30_1   int64
#  76   kq30_2   int64
#  77   kq31_1   int64
#  78   kq31_2   int64
#  79   kq32_1   int64
#  80   kq32_2   int64
#  81   kq33_1   int64
#  82   kq33_2   int64
#  83   bq1      int64
#  84   bq2      int64
#  85   bq3      int64
#  86   bq4      int64
#  87   bq4_1a   object
#  88   bq4_1b   object
#  89   bq4_1c   object
#  90   bq5      int64
#  91   bq5_1    int64
#  92   bq5_2    object
#  93   bq6      int64
#  94   bq7      int64
#  95   bq8_1    int64
#  96   bq8_2    int64
#  97   bq8_3    int64
#  98   bq9      int64
#  99   bq10     int64
#  100  bq11     int64
#  101  bq12_1   int64
#  102  bq12_2   int64
#  103  bq12_3   int64
#  104  bq12_4   int64
#  105  bq12_5   int64
#  106  bq13_1   int64
#  107  bq13_2   int64
#  108  bq13_3   int64
#  109  bq14_1   int64
#  110  bq14_2   int64
#  111  bq14_3   int64
#  112  bq14_4   int64
#  113  bq14_5   int64
#  114  bq15     int64
#  115  bq16_1   int64
#  116  bq16_2   int64
#  117  bq16_3   int64
#  118  bq16_4   int64
#  119  bq16_5   int64
#  120  bq17     int64
#  121  bq18_1   int64
#  122  bq18_2   int64
#  123  bq18_3   int64
#  124  bq18_4   int64
#  125  bq18_5   int64
#  126  bq18_6   int64
#  127  bq18_7   int64
#  128  bq18_8   int64
#  129  bq18_9   int64
#  130  bq18_10  object
#  131  bq19     int64
#  132  bq20     int64
#  133  bq20_1   object
#  134  bq21_1   int64
#  135  bq21_2   int64
#  136  bq21_3   int64
#  137  bq22     object
#  138  bq23     object
#  139  bq24     object
#  140  bq25     int64
#  141  bq26     int64
#  142  bq27     int64
#  143  bq27_1   object
#  144  bq28     int64
#  145  bq28_1   int64
#  146  bq28_2   int64
#  147  bq29     int64
#  148  bq30     int64
#  149  bq31_1   int64
#  150  bq31_2   int64
#  151  bq31_3   int64
# dtypes: int64(142), object(10)
# memory usage: 9.9+ MB

# %%
df_utf = pd.read_csv("know_2019_test_enutf.csv")
df_utf.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8554 entries, 0 to 8553
# Data columns (total 152 columns):
#  #    Column   Dtype
# ---   ------   -----
#  0    idx      int64
#  1    sq1      int64
#  2    sq2      int64
#  3    sq3      int64
#  4    sq4      int64
#  5    sq5      int64
#  6    sq6      int64
#  7    sq7      int64
#  8    sq8      int64
#  9    sq9      int64
#  10   sq10     int64
#  11   sq11     int64
#  12   sq12     int64
#  13   sq13     int64
#  14   sq14     int64
#  15   sq15     int64
#  16   sq16     int64
#  17   kq1_1    int64
#  18   kq1_2    int64
#  19   kq2_1    int64
#  20   kq2_2    int64
#  21   kq3_1    int64
#  22   kq3_2    int64
#  23   kq4_1    int64
#  24   kq4_2    int64
#  25   kq5_1    int64
#  26   kq5_2    int64
#  27   kq6_1    int64
#  28   kq6_2    int64
#  29   kq7_1    int64
#  30   kq7_2    int64
#  31   kq8_1    int64
#  32   kq8_2    int64
#  33   kq9_1    int64
#  34   kq9_2    int64
#  35   kq10_1   int64
#  36   kq10_2   int64
#  37   kq11_1   int64
#  38   kq11_2   int64
#  39   kq12_1   int64
#  40   kq12_2   int64
#  41   kq13_1   int64
#  42   kq13_2   int64
#  43   kq14_1   int64
#  44   kq14_2   int64
#  45   kq15_1   int64
#  46   kq15_2   int64
#  47   kq16_1   int64
#  48   kq16_2   int64
#  49   kq17_1   int64
#  50   kq17_2   int64
#  51   kq18_1   int64
#  52   kq18_2   int64
#  53   kq19_1   int64
#  54   kq19_2   int64
#  55   kq20_1   int64
#  56   kq20_2   int64
#  57   kq21_1   int64
#  58   kq21_2   int64
#  59   kq22_1   int64
#  60   kq22_2   int64
#  61   kq23_1   int64
#  62   kq23_2   int64
#  63   kq24_1   int64
#  64   kq24_2   int64
#  65   kq25_1   int64
#  66   kq25_2   int64
#  67   kq26_1   int64
#  68   kq26_2   int64
#  69   kq27_1   int64
#  70   kq27_2   int64
#  71   kq28_1   int64
#  72   kq28_2   int64
#  73   kq29_1   int64
#  74   kq29_2   int64
#  75   kq30_1   int64
#  76   kq30_2   int64
#  77   kq31_1   int64
#  78   kq31_2   int64
#  79   kq32_1   int64
#  80   kq32_2   int64
#  81   kq33_1   int64
#  82   kq33_2   int64
#  83   bq1      int64
#  84   bq2      int64
#  85   bq3      int64
#  86   bq4      int64
#  87   bq4_1a   object
#  88   bq4_1b   object
#  89   bq4_1c   object
#  90   bq5      int64
#  91   bq5_1    int64
#  92   bq5_2    object
#  93   bq6      int64
#  94   bq7      int64
#  95   bq8_1    int64
#  96   bq8_2    int64
#  97   bq8_3    int64
#  98   bq9      int64
#  99   bq10     int64
#  100  bq11     int64
#  101  bq12_1   int64
#  102  bq12_2   int64
#  103  bq12_3   int64
#  104  bq12_4   int64
#  105  bq12_5   int64
#  106  bq13_1   int64
#  107  bq13_2   int64
#  108  bq13_3   int64
#  109  bq14_1   int64
#  110  bq14_2   int64
#  111  bq14_3   int64
#  112  bq14_4   int64
#  113  bq14_5   int64
#  114  bq15     int64
#  115  bq16_1   int64
#  116  bq16_2   int64
#  117  bq16_3   int64
#  118  bq16_4   int64
#  119  bq16_5   int64
#  120  bq17     int64
#  121  bq18_1   int64
#  122  bq18_2   int64
#  123  bq18_3   int64
#  124  bq18_4   int64
#  125  bq18_5   int64
#  126  bq18_6   int64
#  127  bq18_7   int64
#  128  bq18_8   int64
#  129  bq18_9   int64
#  130  bq18_10  object
#  131  bq19     int64
#  132  bq20     int64
#  133  bq20_1   object
#  134  bq21_1   int64
#  135  bq21_2   int64
#  136  bq21_3   int64
#  137  bq22     object
#  138  bq23     object
#  139  bq24     object
#  140  bq25     int64
#  141  bq26     int64
#  142  bq27     int64
#  143  bq27_1   object
#  144  bq28     int64
#  145  bq28_1   int64
#  146  bq28_2   int64
#  147  bq29     int64
#  148  bq30     int64
#  149  bq31_1   int64
#  150  bq31_2   int64
#  151  bq31_3   int64
# dtypes: int64(142), object(10)
# memory usage: 9.9+ MB
