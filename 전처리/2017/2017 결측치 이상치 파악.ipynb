# %%
import pandas as pd

# %%
know_2017 = pd.read_csv('../know_Data/train/KNOW_2017.csv')

# %%
know_2017
# Out:
#        idx  aq1_1 aq1_2  aq2_1 aq2_2  aq3_1 aq3_2  aq4_1 aq4_2  aq5_1  ...  \
# 0        0      3     3      3     3      3     3      4     4      3  ...
# 1        1      4     5      4     5      3     4      3     4      3  ...
# 2        2      3     4      3     4      3     4      5     6      4  ...
# 3        3      3     3      3     3      3     5      4     5      4  ...
# 4        4      4     5      3     4      3     4      4     5      3  ...
# ...    ...    ...   ...    ...   ...    ...   ...    ...   ...    ...  ...
# 9481  9481      3     5      2     4      3     3      2     2      2  ...
# 9482  9482      5     5      5     5      5     5      3     4      4  ...
# 9483  9483      3     3      4     6      3     3      4     5      4  ...
# 9484  9484      3     5      3     5      4     5      3     4      3  ...
# 9485  9485      3     4      3     4      3     4      3     4      3  ...
#
# ...

# %%
for col in know_2017:
        know_2017[col].replace(' ', 0, inplace = True)

# %%
know_2017.loc[:,:"aq41_2"].columns
# Out:
# Index(['idx', 'aq1_1', 'aq1_2', 'aq2_1', 'aq2_2', 'aq3_1', 'aq3_2', 'aq4_1',
#        'aq4_2', 'aq5_1', 'aq5_2', 'aq6_1', 'aq6_2', 'aq7_1', 'aq7_2', 'aq8_1',
#        'aq8_2', 'aq9_1', 'aq9_2', 'aq10_1', 'aq10_2', 'aq11_1', 'aq11_2',
#        'aq12_1', 'aq12_2', 'aq13_1', 'aq13_2', 'aq14_1', 'aq14_2', 'aq15_1',
#        'aq15_2', 'aq16_1', 'aq16_2', 'aq17_1', 'aq17_2', 'aq18_1', 'aq18_2',
#        'aq19_1', 'aq19_2', 'aq20_1', 'aq20_2', 'aq21_1', 'aq21_2', 'aq22_1',
#        'aq22_2', 'aq23_1', 'aq23_2', 'aq24_1', 'aq24_2', 'aq25_1', 'aq25_2',
#        'aq26_1', 'aq26_2', 'aq27_1', 'aq27_2', 'aq28_1', 'aq28_2', 'aq29_1',
#        'aq29_2', 'aq30_1', 'aq30_2', 'aq31_1', 'aq31_2', 'aq32_1', 'aq32_2',
#        'aq33_1', 'aq33_2', 'aq34_1', 'aq34_2', 'aq35_1', 'aq35_2', 'aq36_1',
#        'aq36_2', 'aq37_1', 'aq37_2', 'aq38_1', 'aq38_2', 'aq39_1', 'aq39_2',
#        'aq40_1', 'aq40_2', 'aq41_1', 'aq41_2'],
#       dtype='object')

# %%
for col in know_2017.loc[:,:"aq41_2"].columns :
    know_2017[col]=know_2017[col].astype(int)

# %%
know_2017.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 156 columns):
#  #    Column    Dtype
# ---   ------    -----
#  0    idx       int32
#  1    aq1_1     int32
#  2    aq1_2     int32
#  3    aq2_1     int32
#  4    aq2_2     int32
#  5    aq3_1     int32
#  6    aq3_2     int32
#  7    aq4_1     int32
#  8    aq4_2     int32
#  9    aq5_1     int32
#  10   aq5_2     int32
#  11   aq6_1     int32
#  12   aq6_2     int32
#  13   aq7_1     int32
#  14   aq7_2     int32
#  15   aq8_1     int32
#  16   aq8_2     int32
#  17   aq9_1     int32
#  18   aq9_2     int32
#  19   aq10_1    int32
#  20   aq10_2    int32
#  21   aq11_1    int32
#  22   aq11_2    int32
#  23   aq12_1    int32
#  24   aq12_2    int32
#  25   aq13_1    int32
#  26   aq13_2    int32
#  27   aq14_1    int32
#  28   aq14_2    int32
#  29   aq15_1    int32
#  30   aq15_2    int32
#  31   aq16_1    int32
#  32   aq16_2    int32
#  33   aq17_1    int32
# ...

# %%
# 주관식문항 

str_li =['bq4_1a','bq4_1b','bq4_1c','bq5_2', 'bq19_1','bq30','bq31','bq32','bq33','bq34','bq38_1']

# %%
for i in know_2017.columns : 
    if i not in str_li : 
        know_2017[i] = know_2017[i].astype(int)

# %%
know_2017.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 156 columns):
#  #    Column    Dtype
# ---   ------    -----
#  0    idx       int32
#  1    aq1_1     int32
#  2    aq1_2     int32
#  3    aq2_1     int32
#  4    aq2_2     int32
#  5    aq3_1     int32
#  6    aq3_2     int32
#  7    aq4_1     int32
#  8    aq4_2     int32
#  9    aq5_1     int32
#  10   aq5_2     int32
#  11   aq6_1     int32
#  12   aq6_2     int32
#  13   aq7_1     int32
#  14   aq7_2     int32
#  15   aq8_1     int32
#  16   aq8_2     int32
#  17   aq9_1     int32
#  18   aq9_2     int32
#  19   aq10_1    int32
#  20   aq10_2    int32
#  21   aq11_1    int32
#  22   aq11_2    int32
#  23   aq12_1    int32
#  24   aq12_2    int32
#  25   aq13_1    int32
#  26   aq13_2    int32
#  27   aq14_1    int32
#  28   aq14_2    int32
#  29   aq15_1    int32
#  30   aq15_2    int32
#  31   aq16_1    int32
#  32   aq16_2    int32
#  33   aq17_1    int32
# ...

# %%
# know_2017.iloc[3985].aq41_1 = 3

# %%
know_2017.iloc[3985, 81] = 3

# %%
know_2017.iloc[3985, 81]
# Out:
# 3

# %%
know_2017[(know_2017.aq11_1.isin([2,3,4,5])) & (know_2017.aq11_2==0)]['aq11_2']
# Out:
# 89      0
# 577     0
# 2422    0
# 4568    0
# Name: aq11_2, dtype: int32

# %%
know_2017.iloc[[89,577,2422,4568], 22] = 4

# %%
know_2017[(know_2017.aq14_1.isin([2,3,4,5])) & (know_2017.aq14_2==0)]['aq14_2']
# Out:
# 3137    0
# 4564    0
# 6539    0
# Name: aq14_2, dtype: int32

# %%
know_2017.iloc[[3137,4564,6539], 28]=4

# %%
know_2017[(know_2017.aq27_1.isin([2,3,4,5])) & (know_2017.aq27_2==0)]['aq27_2']
# Out:
# 715     0
# 792     0
# 3960    0
# 4060    0
# 5388    0
# 6383    0
# 9449    0
# Name: aq27_2, dtype: int32

# %%
know_2017.iloc[[715,792,3960,4060,5388,6383,9449], 54]=4

# %%
know_2017[(know_2017.aq32_1.isin([2,3,4,5])) & (know_2017.aq32_2==0)]['aq32_2']
# Out:
# 1458    0
# 2680    0
# 3523    0
# 3656    0
# 5301    0
# 6368    0
# 6711    0
# 6864    0
# 7435    0
# 9316    0
# 9319    0
# Name: aq32_2, dtype: int32

# %%
know_2017.iloc[[1458,2680,3523,3656,5301,6368,6711,6864,7435,9316,9319], 64]=4

# %%
know_2017[(know_2017.aq41_1.isin([2,3,4,5])) & (know_2017.aq41_2==0)]['aq41_2']
# Out:
# 1798    0
# 6894    0
# 7118    0
# 8289    0
# Name: aq41_2, dtype: int32

# %%
know_2017.iloc[[1798,6894,7118,8289], 82]=4

# %%
null_li = know_2017[(know_2017.bq39_1==1) & (know_2017.bq41_1==0)]['bq41_1'].index

# %%
know_2017.iloc[:,152]
# Out:
# 0       4000
# 1          0
# 2       4000
# 3       7000
# 4       4000
#         ...
# 9481    5200
# 9482    4000
# 9483    2700
# 9484    6800
# 9485    4000
# Name: bq41_1, Length: 9486, dtype: int32

# %%
for i in null_li:
     know_2017.iloc[i,152]=round(know_2017[(know_2017.bq1 ==know_2017.iloc[i,83])&(know_2017.bq41_1!=0)].bq41_1.mean())

# %%
null_li = know_2017[(know_2017.bq39_1==1) & (know_2017.bq41_1==0)]['bq41_1'].index
null_li
# Out:
# Int64Index([], dtype='int64')

# %%
null_li2 =know_2017[(know_2017.bq39_1==1) & (know_2017.bq41_3==0)].index

# %%
for i in null_li2:
    know_2017.iloc[i,154]=round(know_2017[(know_2017.bq1 ==know_2017.iloc[i,83])&(know_2017.bq41_3!=0)].bq41_3.mean())

# %%
null_li2 =know_2017[(know_2017.bq39_1==1) & (know_2017.bq41_3==0)].index

# %%
null_li2
# Out:
# Int64Index([], dtype='int64')

# %%
null_li3 = know_2017[(know_2017.bq39_1==2) & (know_2017.bq41_2==0)].index
null_li3
# Out:
# Int64Index([ 466,  664,  810,  876,  877,  907, 1030, 1195, 1533, 1575, 1695,
#             2003, 2482, 2597, 2738, 3331, 3818, 4025, 4153, 4669, 4687, 4738,
#             5131, 5361, 5403, 6362, 6483, 6516, 6591, 7446, 7455, 7627, 7973,
#             8075, 8224, 9080, 9341],
#            dtype='int64')

# %%
for i in null_li3:
    know_2017.iloc[i,153]=round(know_2017[(know_2017.bq1 ==know_2017.iloc[i,83])&(know_2017.bq41_2!=0)].bq41_2.mean())

# %%
null_li3 = know_2017[(know_2017.bq39_1==2) & (know_2017.bq41_2==0)].index
null_li3
# Out:
# Int64Index([], dtype='int64')

# %%
know_2017.knowcode = know_2017.knowcode.astype(str)

# %%
know_2017.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 156 columns):
#  #    Column    Dtype
# ---   ------    -----
#  0    idx       int32
#  1    aq1_1     int32
#  2    aq1_2     int32
#  3    aq2_1     int32
#  4    aq2_2     int32
#  5    aq3_1     int32
#  6    aq3_2     int32
#  7    aq4_1     int32
#  8    aq4_2     int32
#  9    aq5_1     int32
#  10   aq5_2     int32
#  11   aq6_1     int32
#  12   aq6_2     int32
#  13   aq7_1     int32
#  14   aq7_2     int32
#  15   aq8_1     int32
#  16   aq8_2     int32
#  17   aq9_1     int32
#  18   aq9_2     int32
#  19   aq10_1    int32
#  20   aq10_2    int32
#  21   aq11_1    int32
#  22   aq11_2    int32
#  23   aq12_1    int32
#  24   aq12_2    int32
#  25   aq13_1    int32
#  26   aq13_2    int32
#  27   aq14_1    int32
#  28   aq14_2    int32
#  29   aq15_1    int32
#  30   aq15_2    int32
#  31   aq16_1    int32
#  32   aq16_2    int32
#  33   aq17_1    int32
# ...

# %%
know_2017.to_csv("know_2017_enutf.csv", encoding='utf8')
know_2017.to_csv("know_2017_encp.csv", encoding='cp949')

# %%
df_cp = pd.read_csv("know_2017_encp.csv", encoding='cp949')
df_cp.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 157 columns):
#  #    Column      Dtype
# ---   ------      -----
#  0    Unnamed: 0  int64
#  1    idx         int64
#  2    aq1_1       int64
#  3    aq1_2       int64
#  4    aq2_1       int64
#  5    aq2_2       int64
#  6    aq3_1       int64
#  7    aq3_2       int64
#  8    aq4_1       int64
#  9    aq4_2       int64
#  10   aq5_1       int64
#  11   aq5_2       int64
#  12   aq6_1       int64
#  13   aq6_2       int64
#  14   aq7_1       int64
#  15   aq7_2       int64
#  16   aq8_1       int64
#  17   aq8_2       int64
#  18   aq9_1       int64
#  19   aq9_2       int64
#  20   aq10_1      int64
#  21   aq10_2      int64
#  22   aq11_1      int64
#  23   aq11_2      int64
#  24   aq12_1      int64
#  25   aq12_2      int64
#  26   aq13_1      int64
#  27   aq13_2      int64
#  28   aq14_1      int64
#  29   aq14_2      int64
#  30   aq15_1      int64
#  31   aq15_2      int64
# ...

# %%
df_utf = pd.read_csv("know_2017_enutf.csv")
df_utf.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 157 columns):
#  #    Column      Dtype
# ---   ------      -----
#  0    Unnamed: 0  int64
#  1    idx         int64
#  2    aq1_1       int64
#  3    aq1_2       int64
#  4    aq2_1       int64
#  5    aq2_2       int64
#  6    aq3_1       int64
#  7    aq3_2       int64
#  8    aq4_1       int64
#  9    aq4_2       int64
#  10   aq5_1       int64
#  11   aq5_2       int64
#  12   aq6_1       int64
#  13   aq6_2       int64
#  14   aq7_1       int64
#  15   aq7_2       int64
#  16   aq8_1       int64
#  17   aq8_2       int64
#  18   aq9_1       int64
#  19   aq9_2       int64
#  20   aq10_1      int64
#  21   aq10_2      int64
#  22   aq11_1      int64
#  23   aq11_2      int64
#  24   aq12_1      int64
#  25   aq12_2      int64
#  26   aq13_1      int64
#  27   aq13_2      int64
#  28   aq14_1      int64
#  29   aq14_2      int64
#  30   aq15_1      int64
#  31   aq15_2      int64
# ...

# %%
# know_2017.isnull().sum()[:50]

# 2017은 null로 존재하는 값이 없다
# Out:
# bq11        0
# bq12_1      0
# bq12_2      0
# bq12_3      0
# bq12_4      0
# bq12_5      0
# bq13        0
# bq14        0
# bq15_1      0
# bq15_2      0
# bq15_3      0
# bq16        0
# bq17        0
# bq18_1      0
# bq18_2      0
# bq18_3      0
# bq18_4      0
# bq18_5      0
# bq18_6      0
# bq18_7      0
# bq19        0
# bq19_1      0
# bq20        0
# bq21        0
# bq22        0
# bq23        0
# bq24_1      0
# bq24_2      0
# bq24_3      0
# bq24_4      0
# bq24_5      0
# bq24_6      0
# bq24_7      0
# bq24_8      0
# bq25        0
# bq26        0
# bq27        0
# bq28        0
# bq29        0
# bq30        0
# bq31        0
# bq32        0
# bq33        0
# bq34        0
# bq35        0
# bq36        0
# bq37        0
# bq38        0
# bq38_1      0
# bq39_1      0
# bq39_2      0
# bq40        0
# bq41_1      0
# bq41_2      0
# bq41_3      0
# knowcode    0
# dtype: int64

# %% [markdown]
# ## 이상치 파악

# %%
know_2017.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 156 columns):
#  #    Column    Dtype
# ---   ------    -----
#  0    idx       int64
#  1    aq1_1     int64
#  2    aq1_2     object
#  3    aq2_1     int64
#  4    aq2_2     object
#  5    aq3_1     int64
#  6    aq3_2     object
#  7    aq4_1     int64
#  8    aq4_2     object
#  9    aq5_1     int64
#  10   aq5_2     object
#  11   aq6_1     int64
#  12   aq6_2     object
#  13   aq7_1     int64
#  14   aq7_2     object
#  15   aq8_1     int64
#  16   aq8_2     object
#  17   aq9_1     int64
#  18   aq9_2     object
#  19   aq10_1    int64
#  20   aq10_2    object
#  21   aq11_1    int64
#  22   aq11_2    object
#  23   aq12_1    int64
#  24   aq12_2    object
#  25   aq13_1    int64
#  26   aq13_2    object
#  27   aq14_1    int64
#  28   aq14_2    object
#  29   aq15_1    int64
#  30   aq15_2    object
#  31   aq16_1    int64
#  32   aq16_2    object
#  33   aq17_1    int64
# ...

# %%
for i in know_2017.columns : 
    print(i, len(know_2017[i].value_counts()))
# Out:
# idx 9486
# aq1_1 5
# aq1_2 8
# aq2_1 5
# aq2_2 8
# aq3_1 5
# aq3_2 8
# aq4_1 5
# aq4_2 8
# aq5_1 5
# aq5_2 8
# aq6_1 5
# aq6_2 8
# aq7_1 5
# aq7_2 8
# aq8_1 5
# aq8_2 8
# aq9_1 5
# aq9_2 8
# aq10_1 5
# aq10_2 8
# aq11_1 5
# aq11_2 8
# aq12_1 5
# aq12_2 8
# aq13_1 5
# aq13_2 8
# aq14_1 5
# aq14_2 8
# aq15_1 5
# aq15_2 8
# aq16_1 5
# aq16_2 8
# aq17_1 5
# aq17_2 8
# aq18_1 5
# aq18_2 8
# aq19_1 5
# aq19_2 8
# aq20_1 5
# aq20_2 8
# aq21_1 5
# aq21_2 8
# aq22_1 5
# aq22_2 8
# aq23_1 5
# aq23_2 8
# aq24_1 5
# aq24_2 8
# aq25_1 5
# aq25_2 8
# aq26_1 5
# aq26_2 8
# aq27_1 5
# aq27_2 8
# aq28_1 5
# aq28_2 8
# aq29_1 5
# aq29_2 8
# aq30_1 5
# aq30_2 8
# aq31_1 5
# aq31_2 8
# aq32_1 5
# aq32_2 8
# aq33_1 5
# aq33_2 8
# aq34_1 5
# aq34_2 8
# aq35_1 5
# aq35_2 8
# aq36_1 5
# aq36_2 8
# aq37_1 5
# aq37_2 8
# aq38_1 5
# aq38_2 8
# aq39_1 5
# aq39_2 8
# aq40_1 5
# aq40_2 8
# aq41_1 6
# aq41_2 8
# bq1 21
# bq2 6
# bq3 6
# bq4 2
# bq4_1a 1600
# bq4_1b 581
# bq4_1c 180
# bq5 2
# bq5_1 7
# bq5_2 3848
# ...

# %% [markdown]
# 1. 이상치 파악
#
# aq41_1 자원관리 6 -> 값 33으로 나와있음 : 3으로 수정
#
#
# 2. 주관식
#
# 살릴 주관식중 없다, 없음 -> null or 0 처리
#
# 자격증 순서/ b,c 처리방법
# bq4_1a 자격증 1600
# bq4_1b 자격증 581
# bq4_1c 자격증 180
#
#
# 버림
# bq5_2 훈련사항 3848
# bq19_1 향후일자리변화 8753
# bq30 유사직업명1199
# bq31 사용하는도구 6778
# bq32 직전직업 1569
# bq33 전직가능한직업 1419
# bq34 신직업발굴 340
#
#
# bq38_1 학과 1453
#
#
# 3. 숫자여야하는 값
#
# bq23 직업세계변화 53
# bq37 나이 63
# bq41_1 근로소득 216
# bq41_2 근로소득 96
# bq41_3 근로소득 148
#
#
# 4. 체크해봐야할값 - 어떻게 처리해야할지 고민
# bq39_1 고용형태 2
# bq39_2 고용형태 7
# bq40 계약형태 3
